# %% [markdown]
# # Imports

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %% [markdown]
# # Valores dados del problema

# %%
corr_cont = 0.05
p = 0.5
n = 1000

# %% [markdown]
# #

# %%
binom.rvs(size=10, n=n, p=p)
datos = binom.rvs(n=n, p=p, loc=0, size=n)
plot = sb.distplot(datos, kde=True, color='red')
plot.set(xlabel='Binomial', ylabel='Frecuencia')
# Out:
# C:\Users\LomitoFrito\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Binomial'), Text(0, 0.5, 'Frecuencia')]

# %%
try: 
    c = np.random.normal(p, corr_cont, n)
    plt.ylabel('Frecuencia')
    plt.xlabel('Normal')
    plt.hist(c, 100, normed=True, color='red')
    plt.plot(n, 1/(corr_cont * np.sqrt(2 * np.pi)) * np.exp( - (n - p)**2 / (2 * corr_cont**2) ))
    plt.show()
except:
    print()
